# %% [markdown]
# ### 목표: 화이트 와인 품종 분류 모델
# - 데이터 : 화이트 와인.csv
# - 피 쳐 : pH, alcohol
# - 타 겟 : quality
# - 유 형 : 지도학습 / 분류

# %% [markdown]
# (1) 모듈 로딩 & 데이터

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
dataFile = '../data/winequality-white.csv'

# %%
wineWDFP = pd.read_csv(dataFile, sep='\;', engine='python')
wineWDFP
# Out:
#       "fixed acidity"  "volatile acidity"  "citric acid"  "residual sugar"  \
# 0                 7.0                0.27           0.36              20.7
# 1                 6.3                0.30           0.34               1.6
# 2                 8.1                0.28           0.40               6.9
# 3                 7.2                0.23           0.32               8.5
# 4                 7.2                0.23           0.32               8.5
# ...               ...                 ...            ...               ...
# 4893              6.2                0.21           0.29               1.6
# 4894              6.6                0.32           0.36               8.0
# 4895              6.5                0.24           0.19               1.2
# 4896              5.5                0.29           0.30               1.1
# 4897              6.0                0.21           0.38               0.8
#
# ...

# %%
wineWDF = pd.read_csv(dataFile, usecols=[8, 10, 11], sep='\;', engine='python')
wineWDF
# Out:
#       "pH"  "alcohol"  "quality"
# 0     3.00        8.8          6
# 1     3.30        9.5          6
# 2     3.26       10.1          6
# 3     3.19        9.9          6
# 4     3.19        9.9          6
# ...    ...        ...        ...
# 4893  3.27       11.2          6
# 4894  3.15        9.6          5
# 4895  2.99        9.4          6
# 4896  3.34       12.8          7
# 4897  3.26       11.8          6
#
# [4898 rows x 3 columns]

# %%
wineWDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   "pH"       4898 non-null   float64
#  1   "alcohol"  4898 non-null   float64
#  2   "quality"  4898 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 114.9 KB

# %%
# Out:
# "pH"         3.0
# "alcohol"    8.8
# "quality"    6.0
# Name: 0, dtype: float64

# %% [markdown]
# (2) 데이터 전처리

# %%
plt.scatter(x=wineWDF.iloc[0], y=wineWDF.iloc[1], c=wineWDF.iloc[2])
plt.xlabel('pH')
plt.ylabel('alcohol')
plt.show()

# %% [markdown]
# (3) 기계학습 데이터셋 준비 => 피쳐와 타겟 분리

# %%
# 피쳐/특성/속성 데이터 추출

# %% [markdown]
# (3-1) 학습/테스트 데이터셋 분리

# %%
# 모듈 로딩
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split()

# %%
# 학습 및 테스트 데이터셋 확인
print(f'학습용 데이터셋 ---->\n{X_train.shape}, {y_train}')
print(f'{y_train.value_counts()/y_train.shape[0]}')

print(f'테스트용 데이터셋 ---->\n{X_test.shape}, {y_test}')
print(f'{X_test.value_counts()/y_test.shape[0]}')
